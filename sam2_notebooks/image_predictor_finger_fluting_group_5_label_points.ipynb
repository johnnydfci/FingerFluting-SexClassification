# %%
import os
# if using Apple MPS, fall back to CPU for unsupported ops
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torchvision
print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.5.1+cu124
# Torchvision version: 0.20.1+cu124
# CUDA is available: False
# /home/zhongyi/anaconda3/envs/sam/lib/python3.10/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# select the device for computation
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")

if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
elif device.type == "mps":
    print(
        "\nSupport for MPS devices is preliminary. SAM 2 is trained with CUDA and might "
        "give numerically different outputs and sometimes degraded performance on MPS. "
        "See e.g. https://github.com/pytorch/pytorch/issues/84936 for a discussion."
    )
np.random.seed(3)
# Out:
# using device: cpu

# %% [markdown]
# First, load the SAM 2 model and predictor. Change the path below to point to the SAM 2 checkpoint. Running on CUDA and using the default model are recommended for best results.

# %%
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

sam2_checkpoint = "../checkpoints/sam2.1_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_l.yaml"

sam2_model = build_sam2(model_cfg, sam2_checkpoint, device=device)

predictor = SAM2ImagePredictor(sam2_model)

# %%
import numpy as np
from scipy.ndimage import label, find_objects, binary_erosion, binary_dilation
from scipy.ndimage import generate_binary_structure


def get_largest_connected_component_and_bbox_mask(mask, radius=5, dilation_radius=20):
    # Define a structuring element for erosion and dilation
    struct_elem = generate_binary_structure(2, 1)
    
    # Erode and then dilate the mask to remove small noise
    mask_eroded = binary_erosion(mask, structure=struct_elem, iterations=radius)
    mask_cleaned = binary_dilation(mask_eroded, structure=struct_elem, iterations=radius)
    
    # Label connected components in the cleaned mask
    labeled_array, num_features = label(mask_cleaned)
    
    # Get sizes of connected components
    component_sizes = [(labeled_array == i).sum() for i in range(1, num_features + 1)]
    
    # Identify the largest component by its label
    largest_component_label = np.argmax(component_sizes) + 1
    
    # Create a mask with only the largest connected component
    largest_component = (labeled_array == largest_component_label).astype(np.uint8)
    
    # Find the bounding box of the largest connected component
    bbox = find_objects(labeled_array == largest_component_label)[0]
    min_row, min_col = bbox[0].start, bbox[1].start
    max_row, max_col = bbox[0].stop, bbox[1].stop
    
    # Create an empty array of the same shape as the input mask
    bbox_mask = np.zeros_like(mask, dtype=np.uint8)
    
    # Set the bounding box region to 1
    bbox_mask[min_row:max_row, min_col:max_col] = 1

    # Dilate the bounding box mask by 20 pixels
    bbox_mask_dilated = binary_dilation(bbox_mask, structure=struct_elem, iterations=dilation_radius)
    
    return largest_component, bbox_mask_dilated


def crop_image_by_bbox_per_channel(image, bbox_mask):
    # Find the coordinates of the bounding box from the bbox mask
    rows = np.any(bbox_mask, axis=1)
    cols = np.any(bbox_mask, axis=0)
    min_row, max_row = np.where(rows)[0][[0, -1]]
    min_col, max_col = np.where(cols)[0][[0, -1]]
    
    # Crop each channel of the image using the bounding box coordinates
    cropped_channels = [image[min_row:max_row+1, min_col:max_col+1, c] for c in range(image.shape[2])]
    
    # Stack cropped channels back together to form the final cropped image
    cropped_image = np.stack(cropped_channels, axis=-1)
    
    return cropped_image

def get_center_and_center_rectangle(array, size_factor=0.2):
    h, w = array.shape
    cy, cx = h // 2, w // 2
    rh, rw = int(h * size_factor), int(w * size_factor)
    
    # Calculate the corner points
    top_left = [cx - rw // 2, cy - rh // 2]
    top_right = [top_left[0], top_left[1] + rh]
    bottom_left = [top_left[0] + rw, top_left[1]]
    bottom_right = [top_left[0] + rw, top_left[1] + rh]
    
    # Return the coordinates as a list
    return np.array([[cx, cy], top_left, top_right, bottom_left, bottom_right])

# %% [markdown]
# ## Example image

# %%
from PIL import Image

# Directories for input images and output cropped images
img_dir  = 'quarter_reslution_tactile_img_717/'  # Directory containing the original tactile images
crop_dir = 'quarter_reslution_tactile_img_cropped/'  # Directory to save cropped images

# Iterate through all image files in the input directory, sorted alphabetically
for idx, d in enumerate(sorted(os.listdir(img_dir))):
    # Construct the full path to the input image
    img_path = img_dir + d    
    
    # Modify the file name to append '_cropped' before the file extension
    dot_index = d.rfind('.')  # Find the position of the file extension
    crop_d = d[:dot_index] + '_cropped' + d[dot_index:]  # Add '_cropped' to the file name
    targ_path = crop_dir + crop_d  # Full path for the cropped image output
    
    # Log the index and current file name being processed
    print(idx, d)
    
    # Open the image and convert it to an RGB numpy array
    image = Image.open(img_path)
    image = np.array(image.convert("RGB"))  # Ensure the image is in RGB format
    
    # Set the current image for the SAM2 predictor
    predictor.set_image(image)
    
    # Obtain the central point and central rectangle of the image for generating mask prompts
    input_point = get_center_and_center_rectangle(image[:, :, 0])  # Central coordinates as points
    input_label = np.array([1, 1, 1, 1, 1])  # Labels for each point (indicating 1-class foreground )
    
    # Use the predictor to generate segmentation masks
    masks, scores, logits = predictor.predict(
        point_coords=input_point,  # Input points for segmentation
        point_labels=input_label,  # Labels for the input points
        multimask_output=True,  # Generate multiple mask outputs
    )
    
    # Sort the masks by their confidence scores in descending order
    sorted_ind = np.argsort(scores)[::-1]  # Get indices of scores in descending order
    masks = masks[sorted_ind]  # Reorder masks by score
    scores = scores[sorted_ind]  # Reorder scores
    logits = logits[sorted_ind]  # Reorder logits
    
    # Extract the largest connected component and its bounding box mask from the best mask
    largest_component, bbox_mask = get_largest_connected_component_and_bbox_mask(masks[0])
    
    # Crop the image based on the bounding box mask
    cropped_image = crop_image_by_bbox_per_channel(image, bbox_mask)
    
    # Ensure the cropped image is in the correct format for saving (uint8)
    cropped_image = (cropped_image * 255).astype(np.uint8) if cropped_image.dtype != np.uint8 else cropped_image
    
    # Save the cropped image to the target path
    Image.fromarray(cropped_image).save(targ_path)
    
    # Log the success of the cropping operation, including the shape of the cropped image
    print(idx, d, "Cropped image shape:", cropped_image.shape, 'saved', targ_path)
# Out:
# 0 ID_001_P1099730.JPG
# 0 ID_001_P1099730.JPG Cropped image shape: (2092, 1063, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099730_cropped.JPG
# 1 ID_001_P1099731.JPG
# 1 ID_001_P1099731.JPG Cropped image shape: (2341, 1788, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099731_cropped.JPG
# 2 ID_001_P1099732.JPG
# 2 ID_001_P1099732.JPG Cropped image shape: (2339, 1785, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099732_cropped.JPG
# 3 ID_001_P1099734.JPG
# 3 ID_001_P1099734.JPG Cropped image shape: (2025, 1058, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099734_cropped.JPG
# 4 ID_001_P1099735.JPG
# 4 ID_001_P1099735.JPG Cropped image shape: (2338, 1788, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099735_cropped.JPG
# 5 ID_001_P1099736.JPG
# 5 ID_001_P1099736.JPG Cropped image shape: (2043, 1162, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099736_cropped.JPG
# 6 ID_001_P1099737.JPG
# 6 ID_001_P1099737.JPG Cropped image shape: (1911, 937, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099737_cropped.JPG
# 7 ID_001_P1099738.JPG
# 7 ID_001_P1099738.JPG Cropped image shape: (2338, 1791, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099738_cropped.JPG
# 8 ID_001_P1099739.JPG
# 8 ID_001_P1099739.JPG Cropped image shape: (1993, 1422, 3) saved quarter_reslution_tactile_img_cropped/ID_001_P1099739_cropped.JPG
# 9 ID_002_P1099742.JPG
# 9 ID_002_P1099742.JPG Cropped image shape: (2319, 1769, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099742_cropped.JPG
# 10 ID_002_P1099743.JPG
# 10 ID_002_P1099743.JPG Cropped image shape: (2323, 1770, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099743_cropped.JPG
# 11 ID_002_P1099744.JPG
# 11 ID_002_P1099744.JPG Cropped image shape: (2319, 1766, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099744_cropped.JPG
# 12 ID_002_P1099745.JPG
# 12 ID_002_P1099745.JPG Cropped image shape: (2327, 1767, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099745_cropped.JPG
# 13 ID_002_P1099746.JPG
# 13 ID_002_P1099746.JPG Cropped image shape: (2324, 1762, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099746_cropped.JPG
# 14 ID_002_P1099747.JPG
# 14 ID_002_P1099747.JPG Cropped image shape: (2315, 1762, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099747_cropped.JPG
# 15 ID_002_P1099748.JPG
# 15 ID_002_P1099748.JPG Cropped image shape: (2327, 1768, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099748_cropped.JPG
# 16 ID_002_P1099749.JPG
# 16 ID_002_P1099749.JPG Cropped image shape: (2325, 1765, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099749_cropped.JPG
# 17 ID_002_P1099750.JPG
# 17 ID_002_P1099750.JPG Cropped image shape: (2325, 1768, 3) saved quarter_reslution_tactile_img_cropped/ID_002_P1099750_cropped.JPG
# 18 ID_003_P1099751.JPG
# 18 ID_003_P1099751.JPG Cropped image shape: (2322, 1767, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099751_cropped.JPG
# 19 ID_003_P1099752.JPG
# 19 ID_003_P1099752.JPG Cropped image shape: (2318, 1767, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099752_cropped.JPG
# 20 ID_003_P1099753.JPG
# 20 ID_003_P1099753.JPG Cropped image shape: (2325, 1768, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099753_cropped.JPG
# 21 ID_003_P1099754.JPG
# 21 ID_003_P1099754.JPG Cropped image shape: (2323, 1767, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099754_cropped.JPG
# 22 ID_003_P1099755.JPG
# 22 ID_003_P1099755.JPG Cropped image shape: (2323, 1771, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099755_cropped.JPG
# 23 ID_003_P1099756.JPG
# 23 ID_003_P1099756.JPG Cropped image shape: (2324, 1770, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099756_cropped.JPG
# 24 ID_003_P1099757.JPG
# 24 ID_003_P1099757.JPG Cropped image shape: (2329, 1768, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099757_cropped.JPG
# 25 ID_003_P1099758.JPG
# 25 ID_003_P1099758.JPG Cropped image shape: (2329, 1769, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099758_cropped.JPG
# 26 ID_003_P1099759.JPG
# 26 ID_003_P1099759.JPG Cropped image shape: (2461, 1768, 3) saved quarter_reslution_tactile_img_cropped/ID_003_P1099759_cropped.JPG
# 27 ID_004_P1099761.JPG
# 27 ID_004_P1099761.JPG Cropped image shape: (2318, 1767, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099761_cropped.JPG
# 28 ID_004_P1099762.JPG
# 28 ID_004_P1099762.JPG Cropped image shape: (2337, 1764, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099762_cropped.JPG
# 29 ID_004_P1099763.JPG
# 29 ID_004_P1099763.JPG Cropped image shape: (2322, 1765, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099763_cropped.JPG
# 30 ID_004_P1099764.JPG
# 30 ID_004_P1099764.JPG Cropped image shape: (2325, 1769, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099764_cropped.JPG
# 31 ID_004_P1099765.JPG
# 31 ID_004_P1099765.JPG Cropped image shape: (2326, 1765, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099765_cropped.JPG
# 32 ID_004_P1099766.JPG
# 32 ID_004_P1099766.JPG Cropped image shape: (2325, 1768, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099766_cropped.JPG
# 33 ID_004_P1099767.JPG
# 33 ID_004_P1099767.JPG Cropped image shape: (2326, 1769, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099767_cropped.JPG
# 34 ID_004_P1099768.JPG
# 34 ID_004_P1099768.JPG Cropped image shape: (2321, 1766, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099768_cropped.JPG
# 35 ID_004_P1099769.JPG
# 35 ID_004_P1099769.JPG Cropped image shape: (2351, 1773, 3) saved quarter_reslution_tactile_img_cropped/ID_004_P1099769_cropped.JPG
# 36 ID_005_IMG_6338.jpeg
# 36 ID_005_IMG_6338.jpeg Cropped image shape: (2494, 3634, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6338_cropped.jpeg
# 37 ID_005_IMG_6339.jpeg
# 37 ID_005_IMG_6339.jpeg Cropped image shape: (2546, 3667, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6339_cropped.jpeg
# 38 ID_005_IMG_6340.jpeg
# 38 ID_005_IMG_6340.jpeg Cropped image shape: (2504, 3593, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6340_cropped.jpeg
# 39 ID_005_IMG_6341.jpeg
# 39 ID_005_IMG_6341.jpeg Cropped image shape: (2581, 3669, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6341_cropped.jpeg
# 40 ID_005_IMG_6342.jpeg
# 40 ID_005_IMG_6342.jpeg Cropped image shape: (2659, 3644, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6342_cropped.jpeg
# 41 ID_005_IMG_6343.jpeg
# 41 ID_005_IMG_6343.jpeg Cropped image shape: (2801, 3679, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6343_cropped.jpeg
# 42 ID_005_IMG_6344.jpeg
# 42 ID_005_IMG_6344.jpeg Cropped image shape: (2602, 3830, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6344_cropped.jpeg
# 43 ID_005_IMG_6345.jpeg
# 43 ID_005_IMG_6345.jpeg Cropped image shape: (2429, 3533, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6345_cropped.jpeg
# 44 ID_005_IMG_6346.jpeg
# 44 ID_005_IMG_6346.jpeg Cropped image shape: (2178, 3393, 3) saved quarter_reslution_tactile_img_cropped/ID_005_IMG_6346_cropped.jpeg
# 45 ID_006_P1099770.JPG
# 45 ID_006_P1099770.JPG Cropped image shape: (2330, 1768, 3) saved quarter_reslution_tactile_img_cropped/ID_006_P1099770_cropped.JPG
# 46 ID_010_IMG_6347.jpeg
# 46 ID_010_IMG_6347.jpeg Cropped image shape: (2568, 3700, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6347_cropped.jpeg
# 47 ID_010_IMG_6348.jpeg
# 47 ID_010_IMG_6348.jpeg Cropped image shape: (2831, 3614, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6348_cropped.jpeg
# 48 ID_010_IMG_6349.jpeg
# 48 ID_010_IMG_6349.jpeg Cropped image shape: (2682, 3713, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6349_cropped.jpeg
# 49 ID_010_IMG_6350.jpeg
# 49 ID_010_IMG_6350.jpeg Cropped image shape: (2464, 3667, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6350_cropped.jpeg
# 50 ID_010_IMG_6351.jpeg
# 50 ID_010_IMG_6351.jpeg Cropped image shape: (2924, 3695, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6351_cropped.jpeg
# 51 ID_010_IMG_6352.jpeg
# 51 ID_010_IMG_6352.jpeg Cropped image shape: (2666, 3678, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6352_cropped.jpeg
# 52 ID_010_IMG_6353.jpeg
# 52 ID_010_IMG_6353.jpeg Cropped image shape: (2766, 3677, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6353_cropped.jpeg
# 53 ID_010_IMG_6354.jpeg
# 53 ID_010_IMG_6354.jpeg Cropped image shape: (2603, 3703, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6354_cropped.jpeg
# 54 ID_010_IMG_6355.jpeg
# 54 ID_010_IMG_6355.jpeg Cropped image shape: (2634, 3656, 3) saved quarter_reslution_tactile_img_cropped/ID_010_IMG_6355_cropped.jpeg
# 55 ID_012_P1099772.JPG
# 55 ID_012_P1099772.JPG Cropped image shape: (2233, 1665, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099772_cropped.JPG
# 56 ID_012_P1099773.JPG
# 56 ID_012_P1099773.JPG Cropped image shape: (2247, 1666, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099773_cropped.JPG
# 57 ID_012_P1099774.JPG
# 57 ID_012_P1099774.JPG Cropped image shape: (2228, 1666, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099774_cropped.JPG
# 58 ID_012_P1099775.JPG
# 58 ID_012_P1099775.JPG Cropped image shape: (2227, 1665, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099775_cropped.JPG
# 59 ID_012_P1099776.JPG
# 59 ID_012_P1099776.JPG Cropped image shape: (2229, 1662, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099776_cropped.JPG
# 60 ID_012_P1099777.JPG
# 60 ID_012_P1099777.JPG Cropped image shape: (2224, 1663, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099777_cropped.JPG
# 61 ID_012_P1099778.JPG
# 61 ID_012_P1099778.JPG Cropped image shape: (2239, 1661, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099778_cropped.JPG
# 62 ID_012_P1099779.JPG
# 62 ID_012_P1099779.JPG Cropped image shape: (2232, 1662, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099779_cropped.JPG
# 63 ID_012_P1099780.JPG
# 63 ID_012_P1099780.JPG Cropped image shape: (2230, 1658, 3) saved quarter_reslution_tactile_img_cropped/ID_012_P1099780_cropped.JPG
# 64 ID_013_P1099781.JPG
# 64 ID_013_P1099781.JPG Cropped image shape: (2244, 1666, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099781_cropped.JPG
# 65 ID_013_P1099783.JPG
# 65 ID_013_P1099783.JPG Cropped image shape: (2245, 1666, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099783_cropped.JPG
# 66 ID_013_P1099785.JPG
# 66 ID_013_P1099785.JPG Cropped image shape: (2245, 1663, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099785_cropped.JPG
# 67 ID_013_P1099786.JPG
# 67 ID_013_P1099786.JPG Cropped image shape: (2242, 1660, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099786_cropped.JPG
# 68 ID_013_P1099787.JPG
# 68 ID_013_P1099787.JPG Cropped image shape: (2245, 1666, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099787_cropped.JPG
# 69 ID_013_P1099788.JPG
# 69 ID_013_P1099788.JPG Cropped image shape: (2245, 1666, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099788_cropped.JPG
# 70 ID_013_P1099789.JPG
# 70 ID_013_P1099789.JPG Cropped image shape: (2245, 1665, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099789_cropped.JPG
# 71 ID_013_P1099790.JPG
# 71 ID_013_P1099790.JPG Cropped image shape: (2244, 1665, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099790_cropped.JPG
# 72 ID_013_P1099791.JPG
# 72 ID_013_P1099791.JPG Cropped image shape: (2241, 1664, 3) saved quarter_reslution_tactile_img_cropped/ID_013_P1099791_cropped.JPG
# 73 ID_014_P1099792.JPG
# 73 ID_014_P1099792.JPG Cropped image shape: (2224, 1663, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099792_cropped.JPG
# 74 ID_014_P1099793.JPG
# 74 ID_014_P1099793.JPG Cropped image shape: (2226, 1662, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099793_cropped.JPG
# 75 ID_014_P1099794.JPG
# 75 ID_014_P1099794.JPG Cropped image shape: (2222, 1660, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099794_cropped.JPG
# 76 ID_014_P1099795.JPG
# 76 ID_014_P1099795.JPG Cropped image shape: (2216, 1662, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099795_cropped.JPG
# 77 ID_014_P1099796.JPG
# 77 ID_014_P1099796.JPG Cropped image shape: (2222, 1660, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099796_cropped.JPG
# 78 ID_014_P1099797.JPG
# 78 ID_014_P1099797.JPG Cropped image shape: (2218, 1661, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099797_cropped.JPG
# 79 ID_014_P1099798.JPG
# 79 ID_014_P1099798.JPG Cropped image shape: (2216, 1662, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099798_cropped.JPG
# 80 ID_014_P1099800.JPG
# 80 ID_014_P1099800.JPG Cropped image shape: (2221, 1661, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099800_cropped.JPG
# 81 ID_014_P1099802.JPG
# 81 ID_014_P1099802.JPG Cropped image shape: (2221, 1659, 3) saved quarter_reslution_tactile_img_cropped/ID_014_P1099802_cropped.JPG
# 82 ID_015_P1099803.JPG
# 82 ID_015_P1099803.JPG Cropped image shape: (2214, 1647, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099803_cropped.JPG
# 83 ID_015_P1099804.JPG
# 83 ID_015_P1099804.JPG Cropped image shape: (2221, 1661, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099804_cropped.JPG
# 84 ID_015_P1099805.JPG
# 84 ID_015_P1099805.JPG Cropped image shape: (2224, 1662, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099805_cropped.JPG
# 85 ID_015_P1099806.JPG
# 85 ID_015_P1099806.JPG Cropped image shape: (2223, 1661, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099806_cropped.JPG
# 86 ID_015_P1099807.JPG
# 86 ID_015_P1099807.JPG Cropped image shape: (2220, 1660, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099807_cropped.JPG
# 87 ID_015_P1099808.JPG
# 87 ID_015_P1099808.JPG Cropped image shape: (2226, 1661, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099808_cropped.JPG
# 88 ID_015_P1099809.JPG
# 88 ID_015_P1099809.JPG Cropped image shape: (2225, 1669, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099809_cropped.JPG
# 89 ID_015_P1099810.JPG
# 89 ID_015_P1099810.JPG Cropped image shape: (2225, 1668, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099810_cropped.JPG
# 90 ID_015_P1099811.JPG
# 90 ID_015_P1099811.JPG Cropped image shape: (2218, 1668, 3) saved quarter_reslution_tactile_img_cropped/ID_015_P1099811_cropped.JPG
# 91 ID_016_P1099812.JPG
# 91 ID_016_P1099812.JPG Cropped image shape: (2225, 1667, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099812_cropped.JPG
# 92 ID_016_P1099813.JPG
# 92 ID_016_P1099813.JPG Cropped image shape: (2218, 1665, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099813_cropped.JPG
# 93 ID_016_P1099814.JPG
# 93 ID_016_P1099814.JPG Cropped image shape: (2225, 1574, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099814_cropped.JPG
# 94 ID_016_P1099815.JPG
# 94 ID_016_P1099815.JPG Cropped image shape: (2224, 1568, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099815_cropped.JPG
# 95 ID_016_P1099816.JPG
# 95 ID_016_P1099816.JPG Cropped image shape: (2222, 1525, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099816_cropped.JPG
# 96 ID_016_P1099817.JPG
# 96 ID_016_P1099817.JPG Cropped image shape: (2222, 1580, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099817_cropped.JPG
# 97 ID_016_P1099818.JPG
# 97 ID_016_P1099818.JPG Cropped image shape: (2220, 1578, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099818_cropped.JPG
# 98 ID_016_P1099819.JPG
# 98 ID_016_P1099819.JPG Cropped image shape: (2222, 1582, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099819_cropped.JPG
# 99 ID_016_P1099820.JPG
# 99 ID_016_P1099820.JPG Cropped image shape: (2214, 1572, 3) saved quarter_reslution_tactile_img_cropped/ID_016_P1099820_cropped.JPG
# 100 ID_017_P1099849.JPG
# 100 ID_017_P1099849.JPG Cropped image shape: (2051, 1481, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099849_cropped.JPG
# 101 ID_017_P1099850.JPG
# 101 ID_017_P1099850.JPG Cropped image shape: (2052, 1478, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099850_cropped.JPG
# 102 ID_017_P1099851.JPG
# 102 ID_017_P1099851.JPG Cropped image shape: (2050, 1479, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099851_cropped.JPG
# 103 ID_017_P1099852.JPG
# 103 ID_017_P1099852.JPG Cropped image shape: (2054, 1481, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099852_cropped.JPG
# 104 ID_017_P1099854.JPG
# 104 ID_017_P1099854.JPG Cropped image shape: (2052, 1473, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099854_cropped.JPG
# 105 ID_017_P1099855.JPG
# 105 ID_017_P1099855.JPG Cropped image shape: (1984, 1378, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099855_cropped.JPG
# 106 ID_017_P1099856.JPG
# 106 ID_017_P1099856.JPG Cropped image shape: (2039, 1429, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099856_cropped.JPG
# 107 ID_017_P1099857.JPG
# 107 ID_017_P1099857.JPG Cropped image shape: (2041, 1449, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099857_cropped.JPG
# 108 ID_017_P1099858.JPG
# 108 ID_017_P1099858.JPG Cropped image shape: (2055, 1480, 3) saved quarter_reslution_tactile_img_cropped/ID_017_P1099858_cropped.JPG
# 109 ID_018_P1099821.JPG
# 109 ID_018_P1099821.JPG Cropped image shape: (2221, 1537, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099821_cropped.JPG
# 110 ID_018_P1099822.JPG
# 110 ID_018_P1099822.JPG Cropped image shape: (2224, 1540, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099822_cropped.JPG
# 111 ID_018_P1099823.JPG
# 111 ID_018_P1099823.JPG Cropped image shape: (2223, 1551, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099823_cropped.JPG
# 112 ID_018_P1099824.JPG
# 112 ID_018_P1099824.JPG Cropped image shape: (2220, 1607, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099824_cropped.JPG
# 113 ID_018_P1099825.JPG
# 113 ID_018_P1099825.JPG Cropped image shape: (2226, 1590, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099825_cropped.JPG
# 114 ID_018_P1099826.JPG
# 114 ID_018_P1099826.JPG Cropped image shape: (2227, 1588, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099826_cropped.JPG
# 115 ID_018_P1099827.JPG
# 115 ID_018_P1099827.JPG Cropped image shape: (2221, 1606, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099827_cropped.JPG
# 116 ID_018_P1099828.JPG
# 116 ID_018_P1099828.JPG Cropped image shape: (2219, 1621, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099828_cropped.JPG
# 117 ID_018_P1099829.JPG
# 117 ID_018_P1099829.JPG Cropped image shape: (2218, 1620, 3) saved quarter_reslution_tactile_img_cropped/ID_018_P1099829_cropped.JPG
# 118 ID_019_P1099830.JPG
# 118 ID_019_P1099830.JPG Cropped image shape: (2215, 1614, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099830_cropped.JPG
# 119 ID_019_P1099831.JPG
# 119 ID_019_P1099831.JPG Cropped image shape: (2218, 1616, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099831_cropped.JPG
# 120 ID_019_P1099832.JPG
# 120 ID_019_P1099832.JPG Cropped image shape: (2215, 1616, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099832_cropped.JPG
# 121 ID_019_P1099833.JPG
# 121 ID_019_P1099833.JPG Cropped image shape: (2214, 1616, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099833_cropped.JPG
# 122 ID_019_P1099834.JPG
# 122 ID_019_P1099834.JPG Cropped image shape: (2215, 1616, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099834_cropped.JPG
# 123 ID_019_P1099835.JPG
# 123 ID_019_P1099835.JPG Cropped image shape: (2215, 1615, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099835_cropped.JPG
# 124 ID_019_P1099836.JPG
# 124 ID_019_P1099836.JPG Cropped image shape: (2216, 1616, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099836_cropped.JPG
# 125 ID_019_P1099837.JPG
# 125 ID_019_P1099837.JPG Cropped image shape: (2215, 1617, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099837_cropped.JPG
# 126 ID_019_P1099838.JPG
# 126 ID_019_P1099838.JPG Cropped image shape: (2214, 1617, 3) saved quarter_reslution_tactile_img_cropped/ID_019_P1099838_cropped.JPG
# 127 ID_020_P1099840.JPG
# 127 ID_020_P1099840.JPG Cropped image shape: (2060, 1520, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099840_cropped.JPG
# 128 ID_020_P1099841.JPG
# 128 ID_020_P1099841.JPG Cropped image shape: (2059, 1520, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099841_cropped.JPG
# 129 ID_020_P1099842.JPG
# 129 ID_020_P1099842.JPG Cropped image shape: (2058, 1519, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099842_cropped.JPG
# 130 ID_020_P1099843.JPG
# 130 ID_020_P1099843.JPG Cropped image shape: (2068, 1518, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099843_cropped.JPG
# 131 ID_020_P1099844.JPG
# 131 ID_020_P1099844.JPG Cropped image shape: (2055, 1515, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099844_cropped.JPG
# 132 ID_020_P1099845.JPG
# 132 ID_020_P1099845.JPG Cropped image shape: (2048, 1517, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099845_cropped.JPG
# 133 ID_020_P1099846.JPG
# 133 ID_020_P1099846.JPG Cropped image shape: (2053, 1516, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099846_cropped.JPG
# 134 ID_020_P1099847.JPG
# 134 ID_020_P1099847.JPG Cropped image shape: (2057, 1516, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099847_cropped.JPG
# 135 ID_020_P1099848.JPG
# 135 ID_020_P1099848.JPG Cropped image shape: (2048, 1508, 3) saved quarter_reslution_tactile_img_cropped/ID_020_P1099848_cropped.JPG
# 136 ID_021_P1099859.JPG
# 136 ID_021_P1099859.JPG Cropped image shape: (2042, 1455, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099859_cropped.JPG
# 137 ID_021_P1099860.JPG
# 137 ID_021_P1099860.JPG Cropped image shape: (2050, 1479, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099860_cropped.JPG
# 138 ID_021_P1099861.JPG
# 138 ID_021_P1099861.JPG Cropped image shape: (2055, 1479, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099861_cropped.JPG
# 139 ID_021_P1099862.JPG
# 139 ID_021_P1099862.JPG Cropped image shape: (2052, 1478, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099862_cropped.JPG
# 140 ID_021_P1099863.JPG
# 140 ID_021_P1099863.JPG Cropped image shape: (2044, 1458, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099863_cropped.JPG
# 141 ID_021_P1099864.JPG
# 141 ID_021_P1099864.JPG Cropped image shape: (2044, 1462, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099864_cropped.JPG
# 142 ID_021_P1099865.JPG
# 142 ID_021_P1099865.JPG Cropped image shape: (2049, 1462, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099865_cropped.JPG
# 143 ID_021_P1099866.JPG
# 143 ID_021_P1099866.JPG Cropped image shape: (2047, 1460, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099866_cropped.JPG
# 144 ID_021_P1099867.JPG
# 144 ID_021_P1099867.JPG Cropped image shape: (2047, 1462, 3) saved quarter_reslution_tactile_img_cropped/ID_021_P1099867_cropped.JPG
# 145 ID_022_IMG_6406.jpeg
# 145 ID_022_IMG_6406.jpeg Cropped image shape: (2687, 3918, 3) saved quarter_reslution_tactile_img_cropped/ID_022_IMG_6406_cropped.jpeg
# 146 ID_022_IMG_6408.jpeg
# 146 ID_022_IMG_6408.jpeg Cropped image shape: (2642, 3889, 3) saved quarter_reslution_tactile_img_cropped/ID_022_IMG_6408_cropped.jpeg
# 147 ID_022_IMG_6409.jpeg
# 147 ID_022_IMG_6409.jpeg Cropped image shape: (2780, 3924, 3) saved quarter_reslution_tactile_img_cropped/ID_022_IMG_6409_cropped.jpeg
# 148 ID_022_IMG_6410.jpeg
# 148 ID_022_IMG_6410.jpeg Cropped image shape: (1413, 3760, 3) saved quarter_reslution_tactile_img_cropped/ID_022_IMG_6410_cropped.jpeg
# 149 ID_022_IMG_6411.jpeg
# 149 ID_022_IMG_6411.jpeg Cropped image shape: (2739, 3989, 3) saved quarter_reslution_tactile_img_cropped/ID_022_IMG_6411_cropped.jpeg
# 150 ID_022_P1099868.JPG
# 150 ID_022_P1099868.JPG Cropped image shape: (2057, 1473, 3) saved quarter_reslution_tactile_img_cropped/ID_022_P1099868_cropped.JPG
# 151 ID_022_P1099869.JPG
# 151 ID_022_P1099869.JPG Cropped image shape: (2061, 1463, 3) saved quarter_reslution_tactile_img_cropped/ID_022_P1099869_cropped.JPG
# 152 ID_022_P1099870.JPG
# 152 ID_022_P1099870.JPG Cropped image shape: (2064, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_022_P1099870_cropped.JPG
# 153 ID_022_P1099871.JPG
# 153 ID_022_P1099871.JPG Cropped image shape: (2064, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_022_P1099871_cropped.JPG
# 154 ID_023_P1099967.JPG
# 154 ID_023_P1099967.JPG Cropped image shape: (2053, 1448, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099967_cropped.JPG
# 155 ID_023_P1099968.JPG
# 155 ID_023_P1099968.JPG Cropped image shape: (2023, 1438, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099968_cropped.JPG
# 156 ID_023_P1099969.JPG
# 156 ID_023_P1099969.JPG Cropped image shape: (2041, 1457, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099969_cropped.JPG
# 157 ID_023_P1099970.JPG
# 157 ID_023_P1099970.JPG Cropped image shape: (2040, 1456, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099970_cropped.JPG
# 158 ID_023_P1099971.JPG
# 158 ID_023_P1099971.JPG Cropped image shape: (2043, 1458, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099971_cropped.JPG
# 159 ID_023_P1099972.JPG
# 159 ID_023_P1099972.JPG Cropped image shape: (2025, 1445, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099972_cropped.JPG
# 160 ID_023_P1099973.JPG
# 160 ID_023_P1099973.JPG Cropped image shape: (2040, 1456, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099973_cropped.JPG
# 161 ID_023_P1099974.JPG
# 161 ID_023_P1099974.JPG Cropped image shape: (2022, 1420, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099974_cropped.JPG
# 162 ID_023_P1099975.JPG
# 162 ID_023_P1099975.JPG Cropped image shape: (2039, 1452, 3) saved quarter_reslution_tactile_img_cropped/ID_023_P1099975_cropped.JPG
# 163 ID_024_P1099872.JPG
# 163 ID_024_P1099872.JPG Cropped image shape: (2064, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099872_cropped.JPG
# 164 ID_024_P1099873.JPG
# 164 ID_024_P1099873.JPG Cropped image shape: (2064, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099873_cropped.JPG
# 165 ID_024_P1099874.JPG
# 165 ID_024_P1099874.JPG Cropped image shape: (2064, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099874_cropped.JPG
# 166 ID_024_P1099875.JPG
# 166 ID_024_P1099875.JPG Cropped image shape: (2063, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099875_cropped.JPG
# 167 ID_024_P1099876.JPG
# 167 ID_024_P1099876.JPG Cropped image shape: (2065, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099876_cropped.JPG
# 168 ID_024_P1099877.JPG
# 168 ID_024_P1099877.JPG Cropped image shape: (2064, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099877_cropped.JPG
# 169 ID_024_P1099878.JPG
# 169 ID_024_P1099878.JPG Cropped image shape: (2063, 1467, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099878_cropped.JPG
# 170 ID_024_P1099879.JPG
# 170 ID_024_P1099879.JPG Cropped image shape: (2063, 1467, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099879_cropped.JPG
# 171 ID_024_P1099880.JPG
# 171 ID_024_P1099880.JPG Cropped image shape: (2063, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_024_P1099880_cropped.JPG
# 172 ID_025_IMG_6412.jpeg
# 172 ID_025_IMG_6412.jpeg Cropped image shape: (2794, 3916, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6412_cropped.jpeg
# 173 ID_025_IMG_6413.jpeg
# 173 ID_025_IMG_6413.jpeg Cropped image shape: (2554, 3762, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6413_cropped.jpeg
# 174 ID_025_IMG_6414.jpeg
# 174 ID_025_IMG_6414.jpeg Cropped image shape: (2570, 3724, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6414_cropped.jpeg
# 175 ID_025_IMG_6415.jpeg
# 175 ID_025_IMG_6415.jpeg Cropped image shape: (2575, 3951, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6415_cropped.jpeg
# 176 ID_025_IMG_6416.jpeg
# 176 ID_025_IMG_6416.jpeg Cropped image shape: (2843, 3902, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6416_cropped.jpeg
# 177 ID_025_IMG_6417.jpeg
# 177 ID_025_IMG_6417.jpeg Cropped image shape: (2660, 3892, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6417_cropped.jpeg
# 178 ID_025_IMG_6418.jpeg
# 178 ID_025_IMG_6418.jpeg Cropped image shape: (2631, 3820, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6418_cropped.jpeg
# 179 ID_025_IMG_6419.jpeg
# 179 ID_025_IMG_6419.jpeg Cropped image shape: (2630, 3813, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6419_cropped.jpeg
# 180 ID_025_IMG_6420.jpeg
# 180 ID_025_IMG_6420.jpeg Cropped image shape: (2583, 3778, 3) saved quarter_reslution_tactile_img_cropped/ID_025_IMG_6420_cropped.jpeg
# 181 ID_026_P1099881.JPG
# 181 ID_026_P1099881.JPG Cropped image shape: (2064, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099881_cropped.JPG
# 182 ID_026_P1099882.JPG
# 182 ID_026_P1099882.JPG Cropped image shape: (2062, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099882_cropped.JPG
# 183 ID_026_P1099883.JPG
# 183 ID_026_P1099883.JPG Cropped image shape: (2063, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099883_cropped.JPG
# 184 ID_026_P1099884.JPG
# 184 ID_026_P1099884.JPG Cropped image shape: (2062, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099884_cropped.JPG
# 185 ID_026_P1099885.JPG
# 185 ID_026_P1099885.JPG Cropped image shape: (2063, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099885_cropped.JPG
# 186 ID_026_P1099886.JPG
# 186 ID_026_P1099886.JPG Cropped image shape: (2062, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099886_cropped.JPG
# 187 ID_026_P1099887.JPG
# 187 ID_026_P1099887.JPG Cropped image shape: (2056, 1428, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099887_cropped.JPG
# 188 ID_026_P1099888.JPG
# 188 ID_026_P1099888.JPG Cropped image shape: (2065, 1468, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099888_cropped.JPG
# 189 ID_026_P1099889.JPG
# 189 ID_026_P1099889.JPG Cropped image shape: (2062, 1467, 3) saved quarter_reslution_tactile_img_cropped/ID_026_P1099889_cropped.JPG
# 190 ID_027_P1099891.JPG
# 190 ID_027_P1099891.JPG Cropped image shape: (2063, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099891_cropped.JPG
# 191 ID_027_P1099892.JPG
# 191 ID_027_P1099892.JPG Cropped image shape: (2062, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099892_cropped.JPG
# 192 ID_027_P1099893.JPG
# 192 ID_027_P1099893.JPG Cropped image shape: (2062, 1467, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099893_cropped.JPG
# 193 ID_027_P1099894.JPG
# 193 ID_027_P1099894.JPG Cropped image shape: (2063, 1468, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099894_cropped.JPG
# 194 ID_027_P1099895.JPG
# 194 ID_027_P1099895.JPG Cropped image shape: (2052, 1442, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099895_cropped.JPG
# 195 ID_027_P1099896.JPG
# 195 ID_027_P1099896.JPG Cropped image shape: (2063, 1467, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099896_cropped.JPG
# 196 ID_027_P1099897.JPG
# 196 ID_027_P1099897.JPG Cropped image shape: (2062, 1467, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099897_cropped.JPG
# 197 ID_027_P1099898.JPG
# 197 ID_027_P1099898.JPG Cropped image shape: (2063, 1469, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099898_cropped.JPG
# 198 ID_027_P1099899.JPG
# 198 ID_027_P1099899.JPG Cropped image shape: (2064, 1461, 3) saved quarter_reslution_tactile_img_cropped/ID_027_P1099899_cropped.JPG
# 199 ID_028_P1099900.JPG
# 199 ID_028_P1099900.JPG Cropped image shape: (2066, 1461, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099900_cropped.JPG
# 200 ID_028_P1099901.JPG
# 200 ID_028_P1099901.JPG Cropped image shape: (2059, 1479, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099901_cropped.JPG
# 201 ID_028_P1099902.JPG
# 201 ID_028_P1099902.JPG Cropped image shape: (2059, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099902_cropped.JPG
# 202 ID_028_P1099903.JPG
# 202 ID_028_P1099903.JPG Cropped image shape: (2058, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099903_cropped.JPG
# 203 ID_028_P1099904.JPG
# 203 ID_028_P1099904.JPG Cropped image shape: (2042, 1443, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099904_cropped.JPG
# 204 ID_028_P1099905.JPG
# 204 ID_028_P1099905.JPG Cropped image shape: (2059, 1466, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099905_cropped.JPG
# 205 ID_028_P1099906.JPG
# 205 ID_028_P1099906.JPG Cropped image shape: (2059, 1467, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099906_cropped.JPG
# 206 ID_028_P1099907.JPG
# 206 ID_028_P1099907.JPG Cropped image shape: (2039, 1444, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099907_cropped.JPG
# 207 ID_028_P1099908.JPG
# 207 ID_028_P1099908.JPG Cropped image shape: (2035, 1440, 3) saved quarter_reslution_tactile_img_cropped/ID_028_P1099908_cropped.JPG
# 208 ID_029_P1099911.JPG
# 208 ID_029_P1099911.JPG Cropped image shape: (2058, 1465, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099911_cropped.JPG
# 209 ID_029_P1099912.JPG
# 209 ID_029_P1099912.JPG Cropped image shape: (2056, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099912_cropped.JPG
# 210 ID_029_P1099913.JPG
# 210 ID_029_P1099913.JPG Cropped image shape: (2039, 1437, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099913_cropped.JPG
# 211 ID_029_P1099914.JPG
# 211 ID_029_P1099914.JPG Cropped image shape: (2058, 1464, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099914_cropped.JPG
# 212 ID_029_P1099915.JPG
# 212 ID_029_P1099915.JPG Cropped image shape: (2038, 1449, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099915_cropped.JPG
# 213 ID_029_P1099916.JPG
# 213 ID_029_P1099916.JPG Cropped image shape: (2038, 1448, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099916_cropped.JPG
# 214 ID_029_P1099917.JPG
# 214 ID_029_P1099917.JPG Cropped image shape: (2038, 1441, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099917_cropped.JPG
# 215 ID_029_P1099918.JPG
# 215 ID_029_P1099918.JPG Cropped image shape: (2038, 1437, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099918_cropped.JPG
# 216 ID_029_P1099919.JPG
# 216 ID_029_P1099919.JPG Cropped image shape: (2057, 1463, 3) saved quarter_reslution_tactile_img_cropped/ID_029_P1099919_cropped.JPG
# 217 ID_030_P1099920.JPG
# 217 ID_030_P1099920.JPG Cropped image shape: (2058, 1463, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099920_cropped.JPG
# 218 ID_030_P1099921.JPG
# 218 ID_030_P1099921.JPG Cropped image shape: (2063, 1460, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099921_cropped.JPG
# 219 ID_030_P1099922.JPG
# 219 ID_030_P1099922.JPG Cropped image shape: (2064, 1461, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099922_cropped.JPG
# 220 ID_030_P1099923.JPG
# 220 ID_030_P1099923.JPG Cropped image shape: (2060, 1462, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099923_cropped.JPG
# 221 ID_030_P1099924.JPG
# 221 ID_030_P1099924.JPG Cropped image shape: (2060, 1461, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099924_cropped.JPG
# 222 ID_030_P1099925.JPG
# 222 ID_030_P1099925.JPG Cropped image shape: (2063, 1460, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099925_cropped.JPG
# 223 ID_030_P1099926.JPG
# 223 ID_030_P1099926.JPG Cropped image shape: (2059, 1459, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099926_cropped.JPG
# 224 ID_030_P1099927.JPG
# 224 ID_030_P1099927.JPG Cropped image shape: (2051, 1459, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099927_cropped.JPG
# 225 ID_030_P1099928.JPG
# 225 ID_030_P1099928.JPG Cropped image shape: (2049, 1457, 3) saved quarter_reslution_tactile_img_cropped/ID_030_P1099928_cropped.JPG
# 226 ID_031_P1099929.JPG
# 226 ID_031_P1099929.JPG Cropped image shape: (2050, 1456, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099929_cropped.JPG
# 227 ID_031_P1099930.JPG
# 227 ID_031_P1099930.JPG Cropped image shape: (2052, 1451, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099930_cropped.JPG
# 228 ID_031_P1099931.JPG
# 228 ID_031_P1099931.JPG Cropped image shape: (2053, 1450, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099931_cropped.JPG
# 229 ID_031_P1099932.JPG
# 229 ID_031_P1099932.JPG Cropped image shape: (2056, 1451, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099932_cropped.JPG
# 230 ID_031_P1099933.JPG
# 230 ID_031_P1099933.JPG Cropped image shape: (2056, 1450, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099933_cropped.JPG
# 231 ID_031_P1099934.JPG
# 231 ID_031_P1099934.JPG Cropped image shape: (2041, 1434, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099934_cropped.JPG
# 232 ID_031_P1099935.JPG
# 232 ID_031_P1099935.JPG Cropped image shape: (2044, 1433, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099935_cropped.JPG
# 233 ID_031_P1099936.JPG
# 233 ID_031_P1099936.JPG Cropped image shape: (2052, 1453, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099936_cropped.JPG
# 234 ID_031_P1099937.JPG
# 234 ID_031_P1099937.JPG Cropped image shape: (2051, 1454, 3) saved quarter_reslution_tactile_img_cropped/ID_031_P1099937_cropped.JPG
# 235 ID_032_P1099938.JPG
# 235 ID_032_P1099938.JPG Cropped image shape: (2052, 1453, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099938_cropped.JPG
# 236 ID_032_P1099939.JPG
# 236 ID_032_P1099939.JPG Cropped image shape: (2040, 1434, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099939_cropped.JPG
# 237 ID_032_P1099941.JPG
# 237 ID_032_P1099941.JPG Cropped image shape: (2051, 1452, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099941_cropped.JPG
# 238 ID_032_P1099942.JPG
# 238 ID_032_P1099942.JPG Cropped image shape: (2050, 1450, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099942_cropped.JPG
# 239 ID_032_P1099943.JPG
# 239 ID_032_P1099943.JPG Cropped image shape: (2045, 1437, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099943_cropped.JPG
# 240 ID_032_P1099944.JPG
# 240 ID_032_P1099944.JPG Cropped image shape: (2051, 1453, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099944_cropped.JPG
# 241 ID_032_P1099945.JPG
# 241 ID_032_P1099945.JPG Cropped image shape: (2050, 1456, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099945_cropped.JPG
# 242 ID_032_P1099946.JPG
# 242 ID_032_P1099946.JPG Cropped image shape: (2051, 1454, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099946_cropped.JPG
# 243 ID_032_P1099947.JPG
# 243 ID_032_P1099947.JPG Cropped image shape: (2043, 1443, 3) saved quarter_reslution_tactile_img_cropped/ID_032_P1099947_cropped.JPG
# 244 ID_033_P1099948.JPG
# 244 ID_033_P1099948.JPG Cropped image shape: (2045, 1445, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099948_cropped.JPG
# 245 ID_033_P1099949.JPG
# 245 ID_033_P1099949.JPG Cropped image shape: (2043, 1445, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099949_cropped.JPG
# 246 ID_033_P1099950.JPG
# 246 ID_033_P1099950.JPG Cropped image shape: (2041, 1445, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099950_cropped.JPG
# 247 ID_033_P1099951.JPG
# 247 ID_033_P1099951.JPG Cropped image shape: (2037, 1440, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099951_cropped.JPG
# 248 ID_033_P1099952.JPG
# 248 ID_033_P1099952.JPG Cropped image shape: (2044, 1441, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099952_cropped.JPG
# 249 ID_033_P1099953.JPG
# 249 ID_033_P1099953.JPG Cropped image shape: (2038, 1436, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099953_cropped.JPG
# 250 ID_033_P1099954.JPG
# 250 ID_033_P1099954.JPG Cropped image shape: (2042, 1438, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099954_cropped.JPG
# 251 ID_033_P1099955.JPG
# 251 ID_033_P1099955.JPG Cropped image shape: (2045, 1441, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099955_cropped.JPG
# 252 ID_033_P1099956.JPG
# 252 ID_033_P1099956.JPG Cropped image shape: (2052, 1449, 3) saved quarter_reslution_tactile_img_cropped/ID_033_P1099956_cropped.JPG
# 253 ID_034_P1099958.JPG
# 253 ID_034_P1099958.JPG Cropped image shape: (2056, 1448, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099958_cropped.JPG
# 254 ID_034_P1099959.JPG
# 254 ID_034_P1099959.JPG Cropped image shape: (2055, 1448, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099959_cropped.JPG
# 255 ID_034_P1099960.JPG
# 255 ID_034_P1099960.JPG Cropped image shape: (2056, 1449, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099960_cropped.JPG
# 256 ID_034_P1099961.JPG
# 256 ID_034_P1099961.JPG Cropped image shape: (2034, 1437, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099961_cropped.JPG
# 257 ID_034_P1099962.JPG
# 257 ID_034_P1099962.JPG Cropped image shape: (2035, 1437, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099962_cropped.JPG
# 258 ID_034_P1099963.JPG
# 258 ID_034_P1099963.JPG Cropped image shape: (2037, 1436, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099963_cropped.JPG
# 259 ID_034_P1099964.JPG
# 259 ID_034_P1099964.JPG Cropped image shape: (2040, 1442, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099964_cropped.JPG
# 260 ID_034_P1099965.JPG
# 260 ID_034_P1099965.JPG Cropped image shape: (2037, 1439, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099965_cropped.JPG
# 261 ID_034_P1099966.JPG
# 261 ID_034_P1099966.JPG Cropped image shape: (2035, 1438, 3) saved quarter_reslution_tactile_img_cropped/ID_034_P1099966_cropped.JPG
# 262 ID_035_IMG_6358.jpeg
# 262 ID_035_IMG_6358.jpeg Cropped image shape: (2689, 3871, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6358_cropped.jpeg
# 263 ID_035_IMG_6359.jpeg
# 263 ID_035_IMG_6359.jpeg Cropped image shape: (2333, 3441, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6359_cropped.jpeg
# 264 ID_035_IMG_6360.jpeg
# 264 ID_035_IMG_6360.jpeg Cropped image shape: (2505, 3692, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6360_cropped.jpeg
# 265 ID_035_IMG_6361.jpeg
# 265 ID_035_IMG_6361.jpeg Cropped image shape: (2486, 3679, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6361_cropped.jpeg
# 266 ID_035_IMG_6362.jpeg
# 266 ID_035_IMG_6362.jpeg Cropped image shape: (2555, 3668, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6362_cropped.jpeg
# 267 ID_035_IMG_6363.jpeg
# 267 ID_035_IMG_6363.jpeg Cropped image shape: (2596, 3766, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6363_cropped.jpeg
# 268 ID_035_IMG_6364.jpeg
# 268 ID_035_IMG_6364.jpeg Cropped image shape: (2713, 3890, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6364_cropped.jpeg
# 269 ID_035_IMG_6365.jpeg
# 269 ID_035_IMG_6365.jpeg Cropped image shape: (2689, 3839, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6365_cropped.jpeg
# 270 ID_035_IMG_6367.jpeg
# 270 ID_035_IMG_6367.jpeg Cropped image shape: (2542, 3752, 3) saved quarter_reslution_tactile_img_cropped/ID_035_IMG_6367_cropped.jpeg
# 271 ID_036_IMG_6368.jpeg
# 271 ID_036_IMG_6368.jpeg Cropped image shape: (2653, 3919, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6368_cropped.jpeg
# 272 ID_036_IMG_6369.jpeg
# 272 ID_036_IMG_6369.jpeg Cropped image shape: (2593, 3839, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6369_cropped.jpeg
# 273 ID_036_IMG_6370.jpeg
# 273 ID_036_IMG_6370.jpeg Cropped image shape: (2506, 3738, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6370_cropped.jpeg
# 274 ID_036_IMG_6371.jpeg
# 274 ID_036_IMG_6371.jpeg Cropped image shape: (2584, 3754, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6371_cropped.jpeg
# 275 ID_036_IMG_6372.jpeg
# 275 ID_036_IMG_6372.jpeg Cropped image shape: (2692, 3935, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6372_cropped.jpeg
# 276 ID_036_IMG_6373.jpeg
# 276 ID_036_IMG_6373.jpeg Cropped image shape: (2653, 3833, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6373_cropped.jpeg
# 277 ID_036_IMG_6374.jpeg
# 277 ID_036_IMG_6374.jpeg Cropped image shape: (2628, 3838, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6374_cropped.jpeg
# 278 ID_036_IMG_6375.jpeg
# 278 ID_036_IMG_6375.jpeg Cropped image shape: (2814, 4032, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6375_cropped.jpeg
# 279 ID_036_IMG_6376.jpeg
# 279 ID_036_IMG_6376.jpeg Cropped image shape: (2643, 3953, 3) saved quarter_reslution_tactile_img_cropped/ID_036_IMG_6376_cropped.jpeg
# 280 ID_038_IMG_6397.jpeg
# 280 ID_038_IMG_6397.jpeg Cropped image shape: (2702, 3839, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6397_cropped.jpeg
# 281 ID_038_IMG_6398.jpeg
# 281 ID_038_IMG_6398.jpeg Cropped image shape: (2581, 3587, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6398_cropped.jpeg
# 282 ID_038_IMG_6399.jpeg
# 282 ID_038_IMG_6399.jpeg Cropped image shape: (2751, 3899, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6399_cropped.jpeg
# 283 ID_038_IMG_6400.jpeg
# 283 ID_038_IMG_6400.jpeg Cropped image shape: (2735, 4018, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6400_cropped.jpeg
# 284 ID_038_IMG_6401.jpeg
# 284 ID_038_IMG_6401.jpeg Cropped image shape: (2923, 4028, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6401_cropped.jpeg
# 285 ID_038_IMG_6402.jpeg
# 285 ID_038_IMG_6402.jpeg Cropped image shape: (2895, 3774, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6402_cropped.jpeg
# 286 ID_038_IMG_6403.jpeg
# 286 ID_038_IMG_6403.jpeg Cropped image shape: (2838, 3871, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6403_cropped.jpeg
# 287 ID_038_IMG_6404.jpeg
# 287 ID_038_IMG_6404.jpeg Cropped image shape: (2724, 3897, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6404_cropped.jpeg
# 288 ID_038_IMG_6405.jpeg
# 288 ID_038_IMG_6405.jpeg Cropped image shape: (1951, 2733, 3) saved quarter_reslution_tactile_img_cropped/ID_038_IMG_6405_cropped.jpeg
# 289 ID_040_IMG_6379.jpeg
# 289 ID_040_IMG_6379.jpeg Cropped image shape: (2933, 3925, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6379_cropped.jpeg
# 290 ID_040_IMG_6380.jpeg
# 290 ID_040_IMG_6380.jpeg Cropped image shape: (2819, 4017, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6380_cropped.jpeg
# 291 ID_040_IMG_6381.jpeg
# 291 ID_040_IMG_6381.jpeg Cropped image shape: (2675, 3784, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6381_cropped.jpeg
# 292 ID_040_IMG_6382.jpeg
# 292 ID_040_IMG_6382.jpeg Cropped image shape: (2683, 3818, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6382_cropped.jpeg
# 293 ID_040_IMG_6383.jpeg
# 293 ID_040_IMG_6383.jpeg Cropped image shape: (2760, 3923, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6383_cropped.jpeg
# 294 ID_040_IMG_6384.jpeg
# 294 ID_040_IMG_6384.jpeg Cropped image shape: (2786, 3928, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6384_cropped.jpeg
# 295 ID_040_IMG_6385.jpeg
# 295 ID_040_IMG_6385.jpeg Cropped image shape: (2641, 3834, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6385_cropped.jpeg
# 296 ID_040_IMG_6386.jpeg
# 296 ID_040_IMG_6386.jpeg Cropped image shape: (2882, 4032, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6386_cropped.jpeg
# 297 ID_040_IMG_6387.jpeg
# 297 ID_040_IMG_6387.jpeg Cropped image shape: (2439, 3618, 3) saved quarter_reslution_tactile_img_cropped/ID_040_IMG_6387_cropped.jpeg
# 298 ID_041_IMG_6388.jpeg
# 298 ID_041_IMG_6388.jpeg Cropped image shape: (2529, 3671, 3) saved quarter_reslution_tactile_img_cropped/ID_041_IMG_6388_cropped.jpeg
# 299 ID_041_IMG_6389.jpeg
# 299 ID_041_IMG_6389.jpeg Cropped image shape: (2777, 3832, 3) saved quarter_reslution_tactile_img_cropped/ID_041_IMG_6389_cropped.jpeg
# 300 ID_041_IMG_6390.jpeg
# 300 ID_041_IMG_6390.jpeg Cropped image shape: (2917, 4032, 3) saved quarter_reslution_tactile_img_cropped/ID_041_IMG_6390_cropped.jpeg
# 301 ID_041_IMG_6391.jpeg
# 301 ID_041_IMG_6391.jpeg Cropped image shape: (2606, 3877, 3) saved quarter_reslution_tactile_img_cropped/ID_041_IMG_6391_cropped.jpeg
# 302 ID_041_IMG_6392.jpeg
# 302 ID_041_IMG_6392.jpeg Cropped image shape: (2786, 4025, 3) saved quarter_reslution_tactile_img_cropped/ID_041_IMG_6392_cropped.jpeg
# 303 ID_041_IMG_6393.jpeg
# 303 ID_041_IMG_6393.jpeg Cropped image shape: (2669, 3859, 3) saved quarter_reslution_tactile_img_cropped/ID_041_IMG_6393_cropped.jpeg
# 304 ID_041_IMG_6394.jpeg
# 304 ID_041_IMG_6394.jpeg Cropped image shape: (2606, 3846, 3) saved quarter_reslution_tactile_img_cropped/ID_041_IMG_6394_cropped.jpeg
# 305 ID_041_IMG_6395.jpeg
# ...
# 615 ID_089_P1100295.JPG Cropped image shape: (1931, 1271, 3) saved quarter_reslution_tactile_img_cropped/ID_089_P1100295_cropped.JPG
# 616 ID_089_P1100296.JPG
# 616 ID_089_P1100296.JPG Cropped image shape: (1934, 1280, 3) saved quarter_reslution_tactile_img_cropped/ID_089_P1100296_cropped.JPG
# 617 ID_089_P1100297.JPG
# 617 ID_089_P1100297.JPG Cropped image shape: (1932, 1281, 3) saved quarter_reslution_tactile_img_cropped/ID_089_P1100297_cropped.JPG
# 618 ID_089_P1100298.JPG
# 618 ID_089_P1100298.JPG Cropped image shape: (1939, 1281, 3) saved quarter_reslution_tactile_img_cropped/ID_089_P1100298_cropped.JPG
# 619 ID_089_P1100299.JPG
# 619 ID_089_P1100299.JPG Cropped image shape: (1941, 1276, 3) saved quarter_reslution_tactile_img_cropped/ID_089_P1100299_cropped.JPG
# 620 ID_090_P1100310.JPG
# 620 ID_090_P1100310.JPG Cropped image shape: (1933, 1247, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100310_cropped.JPG
# 621 ID_090_P1100311.JPG
# 621 ID_090_P1100311.JPG Cropped image shape: (1936, 1247, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100311_cropped.JPG
# 622 ID_090_P1100312.JPG
# 622 ID_090_P1100312.JPG Cropped image shape: (1910, 1249, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100312_cropped.JPG
# 623 ID_090_P1100313.JPG
# 623 ID_090_P1100313.JPG Cropped image shape: (1926, 1256, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100313_cropped.JPG
# 624 ID_090_P1100314.JPG
# 624 ID_090_P1100314.JPG Cropped image shape: (1921, 1248, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100314_cropped.JPG
# 625 ID_090_P1100315.JPG
# 625 ID_090_P1100315.JPG Cropped image shape: (1913, 1224, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100315_cropped.JPG
# 626 ID_090_P1100316.JPG
# 626 ID_090_P1100316.JPG Cropped image shape: (1922, 1249, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100316_cropped.JPG
# 627 ID_090_P1100317.JPG
# 627 ID_090_P1100317.JPG Cropped image shape: (1924, 1252, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100317_cropped.JPG
# 628 ID_090_P1100318.JPG
# 628 ID_090_P1100318.JPG Cropped image shape: (1925, 1247, 3) saved quarter_reslution_tactile_img_cropped/ID_090_P1100318_cropped.JPG
# 629 ID_091_P1100319.JPG
# 629 ID_091_P1100319.JPG Cropped image shape: (1923, 1250, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100319_cropped.JPG
# 630 ID_091_P1100320.JPG
# 630 ID_091_P1100320.JPG Cropped image shape: (1920, 1260, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100320_cropped.JPG
# 631 ID_091_P1100321.JPG
# 631 ID_091_P1100321.JPG Cropped image shape: (1919, 1259, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100321_cropped.JPG
# 632 ID_091_P1100322.JPG
# 632 ID_091_P1100322.JPG Cropped image shape: (1921, 1261, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100322_cropped.JPG
# 633 ID_091_P1100323.JPG
# 633 ID_091_P1100323.JPG Cropped image shape: (1922, 1264, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100323_cropped.JPG
# 634 ID_091_P1100324.JPG
# 634 ID_091_P1100324.JPG Cropped image shape: (1925, 1261, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100324_cropped.JPG
# 635 ID_091_P1100325.JPG
# 635 ID_091_P1100325.JPG Cropped image shape: (1907, 1253, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100325_cropped.JPG
# 636 ID_091_P1100326.JPG
# 636 ID_091_P1100326.JPG Cropped image shape: (1924, 1255, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100326_cropped.JPG
# 637 ID_091_P1100327.JPG
# 637 ID_091_P1100327.JPG Cropped image shape: (1922, 1255, 3) saved quarter_reslution_tactile_img_cropped/ID_091_P1100327_cropped.JPG
# 638 ID_092_P1100328.JPG
# 638 ID_092_P1100328.JPG Cropped image shape: (1571, 1138, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100328_cropped.JPG
# 639 ID_092_P1100329.JPG
# 639 ID_092_P1100329.JPG Cropped image shape: (1565, 1116, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100329_cropped.JPG
# 640 ID_092_P1100330.JPG
# 640 ID_092_P1100330.JPG Cropped image shape: (1581, 1150, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100330_cropped.JPG
# 641 ID_092_P1100333.JPG
# 641 ID_092_P1100333.JPG Cropped image shape: (1577, 1147, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100333_cropped.JPG
# 642 ID_092_P1100334.JPG
# 642 ID_092_P1100334.JPG Cropped image shape: (1569, 1142, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100334_cropped.JPG
# 643 ID_092_P1100335.JPG
# 643 ID_092_P1100335.JPG Cropped image shape: (1564, 1140, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100335_cropped.JPG
# 644 ID_092_P1100336.JPG
# 644 ID_092_P1100336.JPG Cropped image shape: (1572, 1143, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100336_cropped.JPG
# 645 ID_092_P1100337.JPG
# 645 ID_092_P1100337.JPG Cropped image shape: (1566, 1132, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100337_cropped.JPG
# 646 ID_092_P1100338.JPG
# 646 ID_092_P1100338.JPG Cropped image shape: (1582, 1149, 3) saved quarter_reslution_tactile_img_cropped/ID_092_P1100338_cropped.JPG
# 647 ID_093_P1100359.JPG
# 647 ID_093_P1100359.JPG Cropped image shape: (1633, 1162, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100359_cropped.JPG
# 648 ID_093_P1100360.JPG
# 648 ID_093_P1100360.JPG Cropped image shape: (1638, 1167, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100360_cropped.JPG
# 649 ID_093_P1100361.JPG
# 649 ID_093_P1100361.JPG Cropped image shape: (1707, 1165, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100361_cropped.JPG
# 650 ID_093_P1100362.JPG
# 650 ID_093_P1100362.JPG Cropped image shape: (1637, 1168, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100362_cropped.JPG
# 651 ID_093_P1100363.JPG
# 651 ID_093_P1100363.JPG Cropped image shape: (1631, 1168, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100363_cropped.JPG
# 652 ID_093_P1100364.JPG
# 652 ID_093_P1100364.JPG Cropped image shape: (1586, 1121, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100364_cropped.JPG
# 653 ID_093_P1100365.JPG
# 653 ID_093_P1100365.JPG Cropped image shape: (1602, 1130, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100365_cropped.JPG
# 654 ID_093_P1100366.JPG
# 654 ID_093_P1100366.JPG Cropped image shape: (1621, 1119, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100366_cropped.JPG
# 655 ID_093_P1100367.JPG
# 655 ID_093_P1100367.JPG Cropped image shape: (1619, 1131, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100367_cropped.JPG
# 656 ID_093_P1100368.JPG
# 656 ID_093_P1100368.JPG Cropped image shape: (1763, 1172, 3) saved quarter_reslution_tactile_img_cropped/ID_093_P1100368_cropped.JPG
# 657 ID_094_P1100369.JPG
# 657 ID_094_P1100369.JPG Cropped image shape: (1634, 1167, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100369_cropped.JPG
# 658 ID_094_P1100370.JPG
# 658 ID_094_P1100370.JPG Cropped image shape: (1637, 1170, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100370_cropped.JPG
# 659 ID_094_P1100371.JPG
# 659 ID_094_P1100371.JPG Cropped image shape: (1813, 1197, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100371_cropped.JPG
# 660 ID_094_P1100372.JPG
# 660 ID_094_P1100372.JPG Cropped image shape: (1636, 1245, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100372_cropped.JPG
# 661 ID_094_P1100373.JPG
# 661 ID_094_P1100373.JPG Cropped image shape: (1640, 1165, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100373_cropped.JPG
# 662 ID_094_P1100374.JPG
# 662 ID_094_P1100374.JPG Cropped image shape: (1642, 1206, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100374_cropped.JPG
# 663 ID_094_P1100375.JPG
# 663 ID_094_P1100375.JPG Cropped image shape: (1777, 1273, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100375_cropped.JPG
# 664 ID_094_P1100376.JPG
# 664 ID_094_P1100376.JPG Cropped image shape: (1732, 1171, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100376_cropped.JPG
# 665 ID_094_P1100377.JPG
# 665 ID_094_P1100377.JPG Cropped image shape: (1623, 1143, 3) saved quarter_reslution_tactile_img_cropped/ID_094_P1100377_cropped.JPG
# 666 ID_095_P1100378.JPG
# 666 ID_095_P1100378.JPG Cropped image shape: (1642, 1237, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100378_cropped.JPG
# 667 ID_095_P1100379.JPG
# 667 ID_095_P1100379.JPG Cropped image shape: (1908, 1266, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100379_cropped.JPG
# 668 ID_095_P1100380.JPG
# 668 ID_095_P1100380.JPG Cropped image shape: (1713, 1228, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100380_cropped.JPG
# 669 ID_095_P1100381.JPG
# 669 ID_095_P1100381.JPG Cropped image shape: (1908, 1382, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100381_cropped.JPG
# 670 ID_095_P1100382.JPG
# 670 ID_095_P1100382.JPG Cropped image shape: (1807, 1381, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100382_cropped.JPG
# 671 ID_095_P1100383.JPG
# 671 ID_095_P1100383.JPG Cropped image shape: (1630, 1121, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100383_cropped.JPG
# 672 ID_095_P1100384.JPG
# 672 ID_095_P1100384.JPG Cropped image shape: (1629, 1127, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100384_cropped.JPG
# 673 ID_095_P1100385.JPG
# 673 ID_095_P1100385.JPG Cropped image shape: (1633, 1123, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100385_cropped.JPG
# 674 ID_095_P1100386.JPG
# 674 ID_095_P1100386.JPG Cropped image shape: (1722, 1427, 3) saved quarter_reslution_tactile_img_cropped/ID_095_P1100386_cropped.JPG
# 675 ID_096_P1100428.JPG
# 675 ID_096_P1100428.JPG Cropped image shape: (1662, 1163, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100428_cropped.JPG
# 676 ID_096_P1100429.JPG
# 676 ID_096_P1100429.JPG Cropped image shape: (1651, 1132, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100429_cropped.JPG
# 677 ID_096_P1100430.JPG
# 677 ID_096_P1100430.JPG Cropped image shape: (1645, 1122, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100430_cropped.JPG
# 678 ID_096_P1100431.JPG
# 678 ID_096_P1100431.JPG Cropped image shape: (1651, 1140, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100431_cropped.JPG
# 679 ID_096_P1100432.JPG
# 679 ID_096_P1100432.JPG Cropped image shape: (1590, 1088, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100432_cropped.JPG
# 680 ID_096_P1100433.JPG
# 680 ID_096_P1100433.JPG Cropped image shape: (1658, 1182, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100433_cropped.JPG
# 681 ID_096_P1100434.JPG
# 681 ID_096_P1100434.JPG Cropped image shape: (1584, 1080, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100434_cropped.JPG
# 682 ID_096_P1100435.JPG
# 682 ID_096_P1100435.JPG Cropped image shape: (1675, 1326, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100435_cropped.JPG
# 683 ID_096_P1100436.JPG
# 683 ID_096_P1100436.JPG Cropped image shape: (1652, 1145, 3) saved quarter_reslution_tactile_img_cropped/ID_096_P1100436_cropped.JPG
# 684 ID_098_P1100387.JPG
# 684 ID_098_P1100387.JPG Cropped image shape: (1614, 1126, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100387_cropped.JPG
# 685 ID_098_P1100388.JPG
# 685 ID_098_P1100388.JPG Cropped image shape: (1599, 1127, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100388_cropped.JPG
# 686 ID_098_P1100389.JPG
# 686 ID_098_P1100389.JPG Cropped image shape: (1668, 1185, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100389_cropped.JPG
# 687 ID_098_P1100390.JPG
# 687 ID_098_P1100390.JPG Cropped image shape: (1632, 1128, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100390_cropped.JPG
# 688 ID_098_P1100391.JPG
# 688 ID_098_P1100391.JPG Cropped image shape: (1597, 1132, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100391_cropped.JPG
# 689 ID_098_P1100392.JPG
# 689 ID_098_P1100392.JPG Cropped image shape: (1614, 1128, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100392_cropped.JPG
# 690 ID_098_P1100393.JPG
# 690 ID_098_P1100393.JPG Cropped image shape: (1676, 1189, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100393_cropped.JPG
# 691 ID_098_P1100394.JPG
# 691 ID_098_P1100394.JPG Cropped image shape: (1582, 1096, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100394_cropped.JPG
# 692 ID_098_P1100395.JPG
# 692 ID_098_P1100395.JPG Cropped image shape: (1668, 1187, 3) saved quarter_reslution_tactile_img_cropped/ID_098_P1100395_cropped.JPG
# 693 ID_099_P1100396.JPG
# 693 ID_099_P1100396.JPG Cropped image shape: (1584, 1122, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100396_cropped.JPG
# 694 ID_099_P1100397.JPG
# 694 ID_099_P1100397.JPG Cropped image shape: (1594, 1115, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100397_cropped.JPG
# 695 ID_099_P1100398.JPG
# 695 ID_099_P1100398.JPG Cropped image shape: (1705, 1311, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100398_cropped.JPG
# 696 ID_099_P1100399.JPG
# 696 ID_099_P1100399.JPG Cropped image shape: (1678, 1143, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100399_cropped.JPG
# 697 ID_099_P1100400.JPG
# 697 ID_099_P1100400.JPG Cropped image shape: (1684, 1144, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100400_cropped.JPG
# 698 ID_099_P1100401.JPG
# 698 ID_099_P1100401.JPG Cropped image shape: (1677, 1142, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100401_cropped.JPG
# 699 ID_099_P1100402.JPG
# 699 ID_099_P1100402.JPG Cropped image shape: (1670, 1141, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100402_cropped.JPG
# 700 ID_099_P1100403.JPG
# 700 ID_099_P1100403.JPG Cropped image shape: (1661, 1333, 3) saved quarter_reslution_tactile_img_cropped/ID_099_P1100403_cropped.JPG
# 701 ID_101_P1100412.JPG
# 701 ID_101_P1100412.JPG Cropped image shape: (1598, 1088, 3) saved quarter_reslution_tactile_img_cropped/ID_101_P1100412_cropped.JPG
# 702 ID_101_P1100413.JPG
# 702 ID_101_P1100413.JPG Cropped image shape: (1594, 1081, 3) saved quarter_reslution_tactile_img_cropped/ID_101_P1100413_cropped.JPG
# 703 ID_101_P1100414.JPG
# 703 ID_101_P1100414.JPG Cropped image shape: (1573, 1074, 3) saved quarter_reslution_tactile_img_cropped/ID_101_P1100414_cropped.JPG
# 704 ID_101_P1100415.JPG
# 704 ID_101_P1100415.JPG Cropped image shape: (1591, 1089, 3) saved quarter_reslution_tactile_img_cropped/ID_101_P1100415_cropped.JPG
# 705 ID_101_P1100416.JPG
# 705 ID_101_P1100416.JPG Cropped image shape: (1577, 1076, 3) saved quarter_reslution_tactile_img_cropped/ID_101_P1100416_cropped.JPG
# 706 ID_101_P1100417.JPG
# 706 ID_101_P1100417.JPG Cropped image shape: (1572, 1094, 3) saved quarter_reslution_tactile_img_cropped/ID_101_P1100417_cropped.JPG
# 707 ID_101_P1100418.JPG
# 707 ID_101_P1100418.JPG Cropped image shape: (1656, 1124, 3) saved quarter_reslution_tactile_img_cropped/ID_101_P1100418_cropped.JPG
# 708 ID_102_P1100419.JPG
# 708 ID_102_P1100419.JPG Cropped image shape: (1684, 1182, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100419_cropped.JPG
# 709 ID_102_P1100420.JPG
# 709 ID_102_P1100420.JPG Cropped image shape: (1650, 1120, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100420_cropped.JPG
# 710 ID_102_P1100421.JPG
# 710 ID_102_P1100421.JPG Cropped image shape: (1654, 1123, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100421_cropped.JPG
# 711 ID_102_P1100422.JPG
# 711 ID_102_P1100422.JPG Cropped image shape: (1663, 1160, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100422_cropped.JPG
# 712 ID_102_P1100423.JPG
# 712 ID_102_P1100423.JPG Cropped image shape: (1653, 1122, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100423_cropped.JPG
# 713 ID_102_P1100424.JPG
# 713 ID_102_P1100424.JPG Cropped image shape: (1646, 1119, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100424_cropped.JPG
# 714 ID_102_P1100425.JPG
# 714 ID_102_P1100425.JPG Cropped image shape: (1652, 1150, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100425_cropped.JPG
# 715 ID_102_P1100426.JPG
# 715 ID_102_P1100426.JPG Cropped image shape: (1611, 1132, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100426_cropped.JPG
# 716 ID_102_P1100427.JPG
# 716 ID_102_P1100427.JPG Cropped image shape: (1653, 1181, 3) saved quarter_reslution_tactile_img_cropped/ID_102_P1100427_cropped.JPG

# %% [markdown]
# To select the truck, choose a point on it. Points are input to the model in (x,y) format and come with labels 1 (foreground point) or 0 (background point). Multiple points can be input; here we use only one. The chosen point will be shown as a star on the image.
